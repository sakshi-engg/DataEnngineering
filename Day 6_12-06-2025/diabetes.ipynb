# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df_rank = df.groupby(['Pregnancies'])
df_rank.mean()
# Out:
#                 Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# Pregnancies
# 0            123.000000      67.153153      22.270270   81.675676  34.290090
# 1            112.748148      67.792593      24.437037   98.674074  31.372593
# 2            110.796117      63.252427      21.601942   85.844660  30.583495
# 3            123.586667      66.586667      20.080000   87.453333  30.425333
# 4            125.117647      70.029412      15.882353   69.441176  32.141176
# 5            118.859649      76.210526      17.385965   57.298246  33.192982
# 6            120.800000      68.420000      17.640000   63.580000  30.290000
# 7            136.444444      70.777778      20.288889   84.466667  32.631111
# 8            131.736842      75.184211      17.315789   92.815789  31.568421
# 9            131.392857      77.892857      20.892857   62.428571  31.707143
# 10           120.916667      70.208333      15.708333   34.791667  30.641667
# ...

# %%
mean_age = df['Age'].mean()
max_age = df['Age'].max()
min_age = df['Age'].min()

print(f"Mean Age: {mean_age}")
print(f"Max Age: {max_age}")
print(f"Min Age: {min_age}")
# Out:
# Mean Age: 33.240885416666664
# Max Age: 81
# Min Age: 21

# %%
df.groupby(['Pregnancies'], sort=False)[['Glucose']].mean()
# Out:
#                 Glucose
# Pregnancies
# 6            120.800000
# 1            112.748148
# 8            131.736842
# 0            123.000000
# 5            118.859649
# 3            123.586667
# 10           120.916667
# 2            110.796117
# 4            125.117647
# 7            136.444444
# 9            131.392857
# 11           126.454545
# 13           125.500000
# 15           136.000000
# 17           163.000000
# 12           113.555556
# 14           137.500000

# %%
df_sub = df[df['Outcome'] > 0.08]
df_sub
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['BMI']
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
df_sorted = df.sort_values( by =['Pregnancies','Glucose'], ascending = [True, False])
df_sorted.head(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 561            0      198             66             32      274  41.3
# 440            0      189            104             25        0  34.3
# 595            0      188             82             14      185  32.0
# 753            0      181             88             44      510  43.3
# 45             0      180             66             39        0  42.0
# 445            0      180             78             63       14  59.4
# 506            0      180             90             26       90  36.5
# 237            0      179             90             27        0  44.1
# 647            0      179             50             36      159  37.8
# 220            0      177             60             29      478  34.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 561                     0.502   28        1
# 440                     0.435   41        1
# 595                     0.682   22        1
# ...

# %%
df_sorted = df.sort_values( by ='Glucose')
df_sorted.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 349            5        0             80             32        0  41.0
# 342            1        0             68             35        0  32.0
# 502            6        0             68             41        0  39.0
# 182            1        0             74             20       23  27.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 349                     0.346   37        1
# 342                     0.389   22        0
# 502                     0.727   41        1
# 182                     0.299   21        0
